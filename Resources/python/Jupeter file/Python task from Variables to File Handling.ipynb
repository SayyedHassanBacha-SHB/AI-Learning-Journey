# %% [markdown]
# # 🐍 Python Programming Tasks
# ### Basics to Intermediate Level
#
# ---
# > **Instructions:** Complete each task by writing your Python code in the provided code cells.
# > Read each task carefully and think before you code!
# > Topics: Variables, Arithmetic, Strings, Lists, Tuples, Indexing, Loops, Functions, Nested Functions, File Handling.
#
# ---

# %% [markdown]
# ## 📦 Topic 1: Variables

# %% [markdown]
# ### Task 1.1 — Introduce Yourself
#
# Create three variables: `name`, `age`, and `city`.
# Store your own (or any made-up) name, age, and city in them.
# Then print a sentence using those variables like:
# `"My name is Sara. I am 20 years old and I live in Lahore."`

# %%
# Task 1.1 — Your code here

# %% [markdown]
# ### Task 1.2 — Favorite Things
#
# Create four variables to store your favorite: `color`, `food`, `sport`, and `number`.
# Print each one on a separate line with a label, for example:
# `"Favorite color: Blue"`
# Make sure each variable uses the correct data type (text or number).

# %%
# Task 1.2 — Your code here

# %% [markdown]
# ### Task 1.3 — Update a Variable
#
# Create a variable called `score` and set it to `10`.
# Print the score.
# Then add `5` to the score and print it again.
# Then multiply the score by `2` and print it one more time.
# You should see three different values printed.

# %%
# Task 1.3 — Your code here

# %% [markdown]
# ---
# ## ➕ Topic 2: Arithmetic Operations

# %% [markdown]
# ### Task 2.1 — Simple Calculator
#
# Create two variables: `a = 18` and `b = 5`.
# Using these two variables, calculate and print:
# - Their **sum**
# - Their **difference**
# - Their **product**
# - Their **division** (result as a decimal)
# Label each result clearly when printing.

# %%
# Task 2.1 — Your code here

# %% [markdown]
# ### Task 2.2 — Bill Splitter
#
# You and your friends went to a restaurant.
# The total bill is `750` and there are `3` friends sharing it equally.
# Create variables for the `total_bill` and `number_of_friends`.
# Calculate how much each person should pay and print it.
# Example output: `"Each person pays: 250.0"`

# %%
# Task 2.2 — Your code here

# %% [markdown]
# ### Task 2.3 — Odd or Even
#
# Ask the user to enter any number using `input()`.
# Convert it to an integer.
# Use the **modulo operator** (`%`) to check if the number is odd or even.
# Print either `"The number is even"` or `"The number is odd"`.

# %%
# Task 2.3 — Your code here

# %% [markdown]
# ---
# ## 🔤 Topic 3: Strings

# %% [markdown]
# ### Task 3.1 — Name Styler
#
# Ask the user to enter their full name using `input()`.
# Then print:
# - The name in **ALL CAPS**
# - The name in **all lowercase**
# - The **total number of characters** in the name (including space)

# %%
# Task 3.1 — Your code here

# %% [markdown]
# ### Task 3.2 — Greeting Card
#
# Ask the user for their name and their favorite season (e.g. summer, winter).
# Use an f-string to print a friendly greeting like:
# `"Hello Ahmed! It looks like you love winter. That's awesome!"`
# Make sure the season is printed with a **capital first letter** even if the user types in lowercase.

# %%
# Task 3.2 — Your code here

# %% [markdown]
# ### Task 3.3 — Word Counter
#
# Create a variable with this sentence:
# `sentence = "I love learning Python because it is fun and easy"`
# Print:
# - The **total number of words** in the sentence
# - Whether the word `"Python"` is found in the sentence (`True` or `False`)
# - The sentence with the word `"easy"` replaced by `"amazing"`

# %%
# Task 3.3 — Your code here
sentence = "I love learning Python because it is fun and easy"

# %% [markdown]
# ---
# ## 📋 Topic 4: Lists

# %% [markdown]
# ### Task 4.1 — My Fruit List
#
# Create a list called `fruits` with 5 fruits of your choice.
# Then:
# - Print the full list
# - Add a new fruit to the end
# - Remove the first fruit
# - Print the updated list and the new total number of fruits

# %%
# Task 4.1 — Your code here

# %% [markdown]
# ### Task 4.2 — Number List
#
# Create a list of 6 numbers: `[4, 17, 2, 39, 8, 25]`
# Print:
# - The **largest** number in the list
# - The **smallest** number in the list
# - The **total sum** of all numbers
# Use built-in Python functions — no need for loops.

# %%
# Task 4.2 — Your code here

# %% [markdown]
# ### Task 4.3 — Class Names
#
# You have a list of student names:
# `["Zara", "Ali", "Mona", "Bilal", "Hina"]`
# - Sort the list **alphabetically** and print it
# - Print the name that comes **first** alphabetically
# - Print the name that comes **last** alphabetically
# - Print the **total number** of students

# %%
# Task 4.3 — Your code here
students = ["Zara", "Ali", "Mona", "Bilal", "Hina"]

# %% [markdown]
# ---
# ## 🔒 Topic 5: Tuples

# %% [markdown]
# ### Task 5.1 — My Info Tuple
#
# Create a tuple called `my_info` that stores your **name**, **age**, and **country** in that order.
# Print each item separately using its **index**.
# Then print the **total number of items** in the tuple using `len()`.

# %%
# Task 5.1 — Your code here

# %% [markdown]
# ### Task 5.2 — Unpack a Tuple
#
# You have this tuple representing a product:
# `product = ("Laptop", "Electronics", 85000)`
# Use **tuple unpacking** to store each value in its own variable: `name`, `category`, `price`.
# Then print:
# `"Product: Laptop | Category: Electronics | Price: 85000"`

# %%
# Task 5.2 — Your code here
product = ("Laptop", "Electronics", 85000)

# %% [markdown]
# ### Task 5.3 — Tuple vs List
#
# Create a **tuple** with the names of 4 months: January, February, March, April.
# Print the **second** and **last** month using indexing.
# Check if `"March"` is in the tuple and print `True` or `False`.
# Then try to change one item in the tuple, wrap it in a `try/except` block, and print a short message explaining what happened.

# %%
# Task 5.3 — Your code here

# %% [markdown]
# ---
# ## 🔎 Topic 6: Indexing

# %% [markdown]
# ### Task 6.1 — Pick Items from a List
#
# You have this list of colors:
# `colors = ["red", "blue", "green", "yellow", "purple", "orange"]`
# Using indexing, print:
# - The **first** color
# - The **last** color (use negative indexing)
# - The **third** color
# - The **first three** colors using slicing

# %%
# Task 6.1 — Your code here
colors = ["red", "blue", "green", "yellow", "purple", "orange"]

# %% [markdown]
# ### Task 6.2 — String Slicing
#
# Create a variable: `word = "Programming"`
# Using slicing and indexing, print:
# - The **first 4 letters**
# - The **last 3 letters** using negative indexing
# - The **entire word reversed**
# - The **letter at index 5**

# %%
# Task 6.2 — Your code here
word = "Programming"

# %% [markdown]
# ### Task 6.3 — Access a Table
#
# You have a simple 2D list (table):
# ```python
# data = [
#     ["Product", "Price"],
#     ["Apple",    30],
#     ["Mango",    60],
#     ["Banana",   20]
# ]
# ```
# Using indexing, print:
# - The header row
# - The price of Mango
# - The name of the last product
# - The entire last row

# %%
# Task 6.3 — Your code here
data = [
    ["Product", "Price"],
    ["Apple",    30],
    ["Mango",    60],
    ["Banana",   20]
]

# %% [markdown]
# ---
# ## 🔁 Topic 7: Loops (for & while)

# %% [markdown]
# ### Task 7.1 — Print a List with a Loop
#
# You have a list of cities: `["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]`
# Use a `for` loop to print each city on its own line.
# Also print a number before each city, starting from 1, like:
# `"1. Karachi"`, `"2. Lahore"`, and so on.

# %%
# Task 7.1 — Your code here

# %% [markdown]
# ### Task 7.2 — Countdown Timer
#
# Use a `while` loop to print a countdown from `10` down to `1`.
# After the loop finishes, print `"Go!"`
# Each number should print on its own line.
# Make sure your loop stops correctly and doesn't run forever!

# %%
# Task 7.2 — Your code here

# %% [markdown]
# ### Task 7.3 — Sum of Numbers
#
# Use a `for` loop and the `range()` function to add up all numbers from `1` to `100`.
# Store the result in a variable called `total`.
# Print the result at the end like: `"The sum from 1 to 100 is: 5050"`
# Do not type the numbers manually — use `range()` to generate them.

# %%
# Task 7.3 — Your code here

# %% [markdown]
# ---
# ## 🛠️ Topic 8: Functions

# %% [markdown]
# ### Task 8.1 — Greeting Function
#
# Write a function called `greet` that takes a person's `name` as a parameter.
# The function should print: `"Hello, [name]! Welcome to Python."`
# Call the function three times with three different names.
# Make sure you define the function before calling it.

# %%
# Task 8.1 — Your code here

# %% [markdown]
# ### Task 8.2 — Add Two Numbers
#
# Write a function called `add` that takes two numbers as parameters and **returns** their sum.
# Call the function with a few different pairs of numbers.
# Print each result like: `"The sum of 4 and 7 is: 11"`
# Make sure the function **returns** the value, not just prints it inside.

# %%
# Task 8.2 — Your code here

# %% [markdown]
# ### Task 8.3 — Even or Odd Function
#
# Write a function called `check_even_odd` that takes a number as a parameter.
# The function should **return** the string `"Even"` or `"Odd"` based on the number.
# Call the function with at least 5 different numbers and print the result each time like:
# `"12 is Even"`, `"7 is Odd"`

# %%
# Task 8.3 — Your code here

# %% [markdown]
# ---
# ## 🪆 Topic 9: Nested Functions

# %% [markdown]
# ### Task 9.1 — Inner Greeter
#
# Write an outer function called `morning_message` that takes a `name` parameter.
# Inside it, write an inner function called `say_hello` that prints `"Good morning, [name]!"`
# The outer function should call `say_hello` and then also print `"Have a great day!"`
# Call `morning_message` with two different names.

# %%
# Task 9.1 — Your code here

# %% [markdown]
# ### Task 9.2 — Price with Tax
#
# Write an outer function called `get_final_price` that takes a `price` parameter.
# Inside it, define an inner function called `add_tax` that adds **16% tax** to the price and returns it.
# The outer function should call `add_tax` and print the final price rounded to 2 decimal places like:
# `"Final price after tax: 116.0"`
# Test it with at least two different prices.

# %%
# Task 9.2 — Your code here

# %% [markdown]
# ### Task 9.3 — Full Name Builder
#
# Write an outer function called `build_profile` that takes `first_name` and `last_name`.
# Inside it, write an inner function called `combine_names` that joins the two names and returns the full name in **Title Case**.
# The outer function should use `combine_names` and print:
# `"Full name: John Doe"`
# Test with at least two name pairs.

# %%
# Task 9.3 — Your code here

# %% [markdown]
# ---
# ## 📁 Topic 10: File Handling

# %% [markdown]
# ### Task 10.1 — Write and Read a File
#
# Write a short message of your choice to a file called `message.txt`.
# The message should be at least 2 lines long.
# After writing, open the file again and print its contents to the screen.
# Use `with` statements for both writing and reading.

# %%
# Task 10.1 — Your code here

# %% [markdown]
# ### Task 10.2 — Append to a File
#
# First, create a file called `notes.txt` and write one line: `"Note 1: Python is fun."`
# Then, **append** two more lines to the same file without deleting the first one:
# `"Note 2: I am learning file handling."`
# `"Note 3: Writing to files is easy."`
# Finally, read and print the full contents of the file.

# %%
# Task 10.2 — Your code here

# %% [markdown]
# ### Task 10.3 — Line Counter
#
# Create a file called `story.txt` and write at least **5 lines** of any short story or sentences into it.
# Then read the file and count how many lines it has.
# Print the total number of lines like: `"The file has 5 lines."`
# Also print each line with its line number, like: `"Line 1: Once upon a time..."`

# %%
# Task 10.3 — Your code here

# %% [markdown]
# ---
# ## ✅ Great job!
#
# You have completed all **30 Python tasks** — from the very basics to intermediate level.
# Keep coding every day and you will keep getting better! 💪🐍
